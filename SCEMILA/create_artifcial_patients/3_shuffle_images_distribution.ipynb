# %%
import numpy as np
import glob
import os
import random
import re
from collections import Counter
import pandas as pd
import pickle

class_labels = ["CBFB_MYH11","control","NPM1","PML_RARA","RUNX1_RUNX1T1"]
n_classes = len(class_labels)

#Function to get list of image_paths in one folder
def get_image_path_list(folder_path):
    tif_files = glob.glob(f"{folder_path}/*.tif")
    return tif_files


#exracts the number of image in the file_path e.g. "image_123.tif"
def extract_number_image(file_path):
    # Use a regular expression to find the number after "image_" and before ".tif"
    match = re.search(r'image_(\d+).tif', file_path)
    return int(match.group(1))

def get_patient_name(path):
    return re.search(r"/data/\w+/([A-Z]{3})", path).group(1)

def get_class_name(path):
    return re.search(r"/data/(\w+)", path).group(1)

def get_classification_patient(patient_folder):
    probs_path = patient_folder + '/single_cell_probabilities.npy'
    sc_probs = np.load(probs_path)
    sc_class= np.argmax(sc_probs, axis=1)
    return sc_class

data_directory = '../../../smalldataset/data'
subtype=data_directory+"/NPM1"
n_patients=5
experiment_name = "experiment_3"
output_folder = '../../../artificialdata/'+experiment_name+'/data'
output_folder_csv='../../../artificialdata/'+experiment_name

# %%
#Iterate over real dataset and store image paths in a dataframe df
df = pd.DataFrame(columns=["patient","AML_subtype", "SC_Label", "image_path"])
for folder_class in class_labels:
    folder_class = os.path.join(data_directory, folder_class)    
    if os.path.isdir(folder_class):
       #print(folder_class)
       AML_subtype=get_class_name(folder_class)
       for folder_patient in os.listdir(folder_class):
            folder_patient = os.path.join(folder_class, folder_patient)
            if os.path.isdir(folder_patient):
                images=get_image_path_list(folder_patient)
                sc_classes=get_classification_patient(folder_patient)
                #print(sc_classes)
                for image in images:
                    number=extract_number_image(image)
                    df.loc[len(df)]=[get_patient_name(folder_patient), AML_subtype, sc_classes[number],image]

# %%
#calculate mean and std for each cell type that will be later used to sample data with normal distribution
sc_class_labels= ['eosinophil granulocyte', 'reactive lymphocyte',
       'neutrophil granulocyte (segmented)', 'typical lymphocyte',
       'other', 'neutrophil granulocyte (band)', 'monocyte',
       'large granulated lymphocyte', 'atypical promyelocyte',
       'basophil granulocyte', 'smudge cell', 'neoplastic lymphocyte',
       'promyelocyte', 'myelocyte', 'myeloblast', 'metamyelocyte',
       'normo', 'plasma cell', 'hair cell', 'bilobed M3v',
       'mononucleosis']
#If single_cell_results does not exist yet run notebook create_single_cell_results
df_sc_res=pd.read_csv(data_directory+"/single_cell_results.csv",index_col=0).drop("patient", axis=1)
df_meanstd = df_sc_res.groupby(["AML_subtype"]).agg(["mean","std"])

# %%
df_meanstd
# Out:
#               eosinophil granulocyte           reactive lymphocyte            \
#                                 mean       std                mean       std
# AML_subtype
# CBFB_MYH11                       1.2  0.836660                 7.0  7.141428
# NPM1                             4.6  5.412947                 4.6  6.542171
# PML_RARA                         1.4  1.516575                 2.8  3.346640
# RUNX1_RUNX1T1                    0.8  1.788854                 1.0  1.414214
# control                         11.6  5.549775                10.0  9.000000
#
#               neutrophil granulocyte (segmented)             \
#                                             mean        std
# AML_subtype
# CBFB_MYH11                                  16.8  16.284962
# NPM1                                        32.2  56.406560
# PML_RARA                                    12.6  11.148991
# RUNX1_RUNX1T1                               10.4  10.899541
# control                                    179.8  70.489006
#
#               typical lymphocyte            other             ... normo  \
#                             mean        std  mean        std  ...  mean
# AML_subtype                                                   ...
# CBFB_MYH11                 105.6  79.651114  21.2  10.009995  ...   1.8
# NPM1                        77.0  64.074176  49.4  34.158454  ...  11.6
# PML_RARA                    39.8  56.459720  88.4  36.637413  ...   9.2
# RUNX1_RUNX1T1               75.8  79.678730  25.6  16.379866  ...   4.0
# control                     50.2  17.412639  66.4  47.395147  ...   0.8
#
#                          plasma cell            hair cell            \
#                      std        mean        std      mean       std
# AML_subtype
# CBFB_MYH11      2.489980         5.2   4.549725       1.2  0.836660
# NPM1           16.009372         7.8   6.180615       7.4  9.864076
# PML_RARA       16.709279         4.4   6.426508       2.4  3.361547
# RUNX1_RUNX1T1   3.535534        14.4  10.922454       3.2  3.114482
# control         1.788854         1.4   2.190890       0.8  0.447214
#
#               bilobed M3v            mononucleosis
#                      mean        std          mean        std
# AML_subtype
# CBFB_MYH11            0.8   1.303840          11.8  16.177144
# NPM1                  2.8   2.588436          12.6  17.826946
# PML_RARA             16.0  28.956864           2.8   3.834058
# RUNX1_RUNX1T1        12.6  12.739702           5.0   4.795832
# control               0.0   0.000000           3.8   3.898718
#
# [5 rows x 42 columns]

# %%
#This cell creates artificial patients and stores the single cell couunts per patient in cell_type_counts_dict, also it counts the selected_images_per_patient as a sanity check
# Dictionary stores cell type counts (how often each cell type appears)
cell_type_counts_dict = {}

# Dictionary stores the selected images and counts them per SC class per patient
selected_images_per_patient = {}

# Iterate over all AML subtypes
for aml_subtype in class_labels:
    output_class_folder = output_folder + "/" + aml_subtype
    # Get distribution
    class_means = df_meanstd.loc[aml_subtype, :].loc[:, "mean"].values
    class_variances = df_meanstd.loc[aml_subtype, :].loc[:, "std"].values
    for patient_number in range(n_patients):
        print(f"Generating data for patient {patient_number+1} of subtype {aml_subtype}...")
        # Calculate how many images from each SC class
        generated_data = np.random.normal(class_means, class_variances, 21).astype(int)
        generated_data = generated_data * (generated_data > 0)
        image_file_paths = []
        # Randomly choose SC image and concatenate them into image_file_paths
        selected_images_count = {}
        for cell_type_number, cell_type in enumerate(sc_class_labels):
            df_cell_type = df[df["SC_Label"] == cell_type_number]
            # print(f"\tImages for cell type {cell_type}...")
            file_path = df_cell_type["image_path"].values
            image_paths = np.random.choice(file_path, size=generated_data[cell_type_number]).tolist()
            print(f"\t\tSelected {len(image_paths)} images for {cell_type}")
            image_file_paths += image_paths
            # Store selected images count per SC class
            selected_images_count[cell_type] = len(image_paths)
        # Store selected images count per SC class per patient
        patient_id = f"{aml_subtype}/patient_{patient_number+1}"
        selected_images_per_patient[patient_id] = selected_images_count
        # Store patient classes and number images for metadata
        new_patient_folder = os.path.join(output_class_folder, f'patient_{patient_number+1}')
        os.makedirs(new_patient_folder, exist_ok=True)

        # Sort the shuffled image paths for the current patient
        image_file_paths.sort()
        # Save the shuffled image paths into a text file
        txt_file_path = os.path.join(new_patient_folder, 'images.txt')
        with open(txt_file_path, 'w') as txt_file:
            for image_path in image_file_paths:
                txt_file.write(image_path + '\n')

        with open(os.path.join(new_patient_folder, "image_file_paths"), 'wb') as fp:
            pickle.dump(image_file_paths, fp)

        # Count cell types in the current patient
        cell_type_count = {cell_type: image_file_paths.count(cell_type) for cell_type in set(image_file_paths)}
        print(f"\tCell type count for patient {patient_number+1}: {cell_type_count}")

        # Add the cell type count to the dictionary with the patient as the key
        # and the cell type count as the value
        cell_type_counts_dict[(aml_subtype, patient_id)] = cell_type_count
        print(f"\tCell type counts dictionary for patient {patient_id}: {cell_type_count}")

# Print selected images count per SC class per patient
print("\nSelected Images Count per SC class per Patient:")
for patient_id, sc_counts in selected_images_per_patient.items():
    print(patient_id)
    for sc_class, count in sc_counts.items():
        print(f"\t{sc_class}: {count}")
# Out:
# Generating data for patient 1 of subtype CBFB_MYH11...
# 		Selected 3 images for eosinophil granulocyte
# 		Selected 4 images for reactive lymphocyte
# 		Selected 8 images for neutrophil granulocyte (segmented)
# 		Selected 42 images for typical lymphocyte
# 		Selected 19 images for other
# 		Selected 12 images for neutrophil granulocyte (band)
# 		Selected 155 images for monocyte
# 		Selected 44 images for large granulated lymphocyte
# 		Selected 8 images for atypical promyelocyte
# 		Selected 0 images for basophil granulocyte
# 		Selected 18 images for smudge cell
# 		Selected 2 images for neoplastic lymphocyte
# 		Selected 0 images for promyelocyte
# 		Selected 1 images for myelocyte
# 		Selected 111 images for myeloblast
# 		Selected 3 images for metamyelocyte
# 		Selected 5 images for normo
# 		Selected 6 images for plasma cell
# 		Selected 0 images for hair cell
# 		Selected 0 images for bilobed M3v
# 		Selected 29 images for mononucleosis
# 	Cell type count for patient 1: {'../../../smalldataset/data/CBFB_MYH11/BJK/image_151.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_134.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_7.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_210.tif': 1, '../../../smalldataset/data/control/AEC/image_415.tif': 1, '../../../smalldataset/data/control/ATM/image_98.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_21.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_28.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_480.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_490.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_80.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_103.tif': 2, '../../../smalldataset/data/PML_RARA/BIK/image_90.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_148.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_213.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_89.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_70.tif': 1, '../../../smalldataset/data/control/ATM/image_259.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_321.tif': 2, '../../../smalldataset/data/NPM1/ALA/image_97.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_207.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_385.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_58.tif': 1, '../../../smalldataset/data/control/AVL/image_319.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_380.tif': 1, '../../../smalldataset/data/control/AEC/image_366.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_216.tif': 1, '../../../smalldataset/data/control/AEC/image_125.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_142.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_203.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_414.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_394.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_303.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_45.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_136.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_218.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_55.tif': 1, '../../../smalldataset/data/control/BXR/image_21.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_467.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_173.tif': 1, '../../../smalldataset/data/control/AEC/image_16.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_8.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_1.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_202.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_408.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_54.tif': 1, '../../../smalldataset/data/PML_RARA/BHS/image_468.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_62.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_370.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_272.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_279.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_290.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_353.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_386.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_330.tif': 2, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_423.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_19.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_411.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_22.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_297.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_93.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_118.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_209.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_304.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_448.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/i ...
# 	Cell type counts dictionary for patient CBFB_MYH11/patient_1: {'../../../smalldataset/data/CBFB_MYH11/BJK/image_151.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_134.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_7.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_210.tif': 1, '../../../smalldataset/data/control/AEC/image_415.tif': 1, '../../../smalldataset/data/control/ATM/image_98.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_21.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_28.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_480.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_490.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_80.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_103.tif': 2, '../../../smalldataset/data/PML_RARA/BIK/image_90.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_148.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_213.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_89.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_70.tif': 1, '../../../smalldataset/data/control/ATM/image_259.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_321.tif': 2, '../../../smalldataset/data/NPM1/ALA/image_97.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_207.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_385.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_58.tif': 1, '../../../smalldataset/data/control/AVL/image_319.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_380.tif': 1, '../../../smalldataset/data/control/AEC/image_366.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_216.tif': 1, '../../../smalldataset/data/control/AEC/image_125.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_142.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_203.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_414.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_394.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_303.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_45.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_136.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_218.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_55.tif': 1, '../../../smalldataset/data/control/BXR/image_21.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_467.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_173.tif': 1, '../../../smalldataset/data/control/AEC/image_16.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_8.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_1.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_202.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_408.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_54.tif': 1, '../../../smalldataset/data/PML_RARA/BHS/image_468.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_62.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_370.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_272.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_279.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_290.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_353.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_386.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_330.tif': 2, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_423.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_19.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_411.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_22.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_297.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_93.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_118.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_209.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_304.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_448.tif': 1, '../../../sma ...
# Generating data for patient 2 of subtype CBFB_MYH11...
# 		Selected 1 images for eosinophil granulocyte
# 		Selected 9 images for reactive lymphocyte
# 		Selected 13 images for neutrophil granulocyte (segmented)
# 		Selected 15 images for typical lymphocyte
# 		Selected 27 images for other
# 		Selected 11 images for neutrophil granulocyte (band)
# 		Selected 76 images for monocyte
# 		Selected 0 images for large granulated lymphocyte
# 		Selected 20 images for atypical promyelocyte
# 		Selected 0 images for basophil granulocyte
# 		Selected 0 images for smudge cell
# 		Selected 2 images for neoplastic lymphocyte
# 		Selected 2 images for promyelocyte
# 		Selected 1 images for myelocyte
# 		Selected 150 images for myeloblast
# 		Selected 6 images for metamyelocyte
# 		Selected 6 images for normo
# 		Selected 12 images for plasma cell
# 		Selected 0 images for hair cell
# 		Selected 0 images for bilobed M3v
# 		Selected 0 images for mononucleosis
# 	Cell type count for patient 2: {'../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_206.tif': 1, '../../../smalldataset/data/control/AVL/image_162.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_374.tif': 2, '../../../smalldataset/data/CBFB_MYH11/BJK/image_321.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_283.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_101.tif': 1, '../../../smalldataset/data/PML_RARA/BHS/image_243.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_279.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_112.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_189.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_261.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_76.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_240.tif': 1, '../../../smalldataset/data/control/ATM/image_245.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_64.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_145.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_16.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_26.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_302.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_86.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_330.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_270.tif': 1, '../../../smalldataset/data/control/AIH/image_49.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_423.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_81.tif': 1, '../../../smalldataset/data/control/ATM/image_343.tif': 1, '../../../smalldataset/data/control/ATM/image_329.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_349.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_297.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_163.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_281.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_213.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_238.tif': 1, '../../../smalldataset/data/control/ATM/image_241.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_161.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_113.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_240.tif': 1, '../../../smalldataset/data/control/BXR/image_85.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_0.tif': 1, '../../../smalldataset/data/control/ATM/image_116.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_209.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_437.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_25.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_85.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_26.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_163.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_445.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_33.tif': 1, '../../../smalldataset/data/control/BXR/image_166.tif': 1, '../../../smalldataset/data/control/AIH/image_15.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_276.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_492.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_275.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_321.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_114.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_139.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_185.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_205.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_378.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_81.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_43.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_488.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_282.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_268.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_121.tif': 1, '../../../smalldataset/data ...
# 	Cell type counts dictionary for patient CBFB_MYH11/patient_2: {'../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_206.tif': 1, '../../../smalldataset/data/control/AVL/image_162.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_374.tif': 2, '../../../smalldataset/data/CBFB_MYH11/BJK/image_321.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_283.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_101.tif': 1, '../../../smalldataset/data/PML_RARA/BHS/image_243.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_279.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_112.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_189.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_261.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_76.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_240.tif': 1, '../../../smalldataset/data/control/ATM/image_245.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_64.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_145.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_16.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_26.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_302.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_86.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_330.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_270.tif': 1, '../../../smalldataset/data/control/AIH/image_49.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_423.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_81.tif': 1, '../../../smalldataset/data/control/ATM/image_343.tif': 1, '../../../smalldataset/data/control/ATM/image_329.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_349.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_297.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_163.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_281.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_213.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_238.tif': 1, '../../../smalldataset/data/control/ATM/image_241.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_161.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_113.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_240.tif': 1, '../../../smalldataset/data/control/BXR/image_85.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_0.tif': 1, '../../../smalldataset/data/control/ATM/image_116.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_209.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_437.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_25.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_85.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_26.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_163.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_445.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_33.tif': 1, '../../../smalldataset/data/control/BXR/image_166.tif': 1, '../../../smalldataset/data/control/AIH/image_15.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_276.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_492.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_275.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_321.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_114.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_139.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_185.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_205.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_378.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_81.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_43.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_488.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_282.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_268.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_121.tif': ...
# Generating data for patient 3 of subtype CBFB_MYH11...
# 		Selected 0 images for eosinophil granulocyte
# 		Selected 12 images for reactive lymphocyte
# 		Selected 2 images for neutrophil granulocyte (segmented)
# 		Selected 19 images for typical lymphocyte
# 		Selected 13 images for other
# 		Selected 5 images for neutrophil granulocyte (band)
# 		Selected 129 images for monocyte
# 		Selected 27 images for large granulated lymphocyte
# 		Selected 1 images for atypical promyelocyte
# 		Selected 0 images for basophil granulocyte
# 		Selected 13 images for smudge cell
# 		Selected 0 images for neoplastic lymphocyte
# 		Selected 0 images for promyelocyte
# 		Selected 0 images for myelocyte
# 		Selected 61 images for myeloblast
# 		Selected 1 images for metamyelocyte
# 		Selected 2 images for normo
# 		Selected 7 images for plasma cell
# 		Selected 1 images for hair cell
# 		Selected 2 images for bilobed M3v
# 		Selected 40 images for mononucleosis
# 	Cell type count for patient 3: {'../../../smalldataset/data/PML_RARA/BIK/image_92.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_397.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_94.tif': 1, '../../../smalldataset/data/PML_RARA/BHS/image_333.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_343.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_246.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_243.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_53.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_429.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_125.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_175.tif': 1, '../../../smalldataset/data/control/ATM/image_261.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_459.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_157.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_281.tif': 1, '../../../smalldataset/data/control/BXR/image_482.tif': 1, '../../../smalldataset/data/control/BXR/image_309.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_272.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_119.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_279.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_309.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_353.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_220.tif': 1, '../../../smalldataset/data/control/AEC/image_291.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_351.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_130.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_315.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_18.tif': 2, '../../../smalldataset/data/NPM1/DPF/image_93.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_233.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_160.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_31.tif': 1, '../../../smalldataset/data/control/ATM/image_171.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_161.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_27.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_378.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_160.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_87.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_367.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_382.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_322.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_341.tif': 2, '../../../smalldataset/data/NPM1/CVW/image_321.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_416.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_180.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_56.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_275.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_53.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_53.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_61.tif': 1, '../../../smalldataset/data/control/AVL/image_254.tif': 1, '../../../smalldataset/data/PML_RARA/BHS/image_355.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_153.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_54.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_495.tif': 2, '../../../smalldataset/data/CBFB_MYH11/BTB/image_192.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_65.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_405.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_148.tif': 1, '../../../smalldataset/data/control/BXR/image_381.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_243.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_262.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_5.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_262.tif': 2, '../../../smalldataset/data/NPM1/ALA/image_487.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_270.tif': 1, '../../../s ...
# 	Cell type counts dictionary for patient CBFB_MYH11/patient_3: {'../../../smalldataset/data/PML_RARA/BIK/image_92.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_397.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_94.tif': 1, '../../../smalldataset/data/PML_RARA/BHS/image_333.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_343.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_246.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_243.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_53.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_429.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_125.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_175.tif': 1, '../../../smalldataset/data/control/ATM/image_261.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_459.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_157.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_281.tif': 1, '../../../smalldataset/data/control/BXR/image_482.tif': 1, '../../../smalldataset/data/control/BXR/image_309.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_272.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_119.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_279.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_309.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_353.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_220.tif': 1, '../../../smalldataset/data/control/AEC/image_291.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_351.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_130.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_315.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_18.tif': 2, '../../../smalldataset/data/NPM1/DPF/image_93.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_233.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_160.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_31.tif': 1, '../../../smalldataset/data/control/ATM/image_171.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_161.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_27.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_378.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_160.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_87.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_367.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_382.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_322.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_341.tif': 2, '../../../smalldataset/data/NPM1/CVW/image_321.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_416.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_180.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_56.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_275.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_53.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_53.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_61.tif': 1, '../../../smalldataset/data/control/AVL/image_254.tif': 1, '../../../smalldataset/data/PML_RARA/BHS/image_355.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_153.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_54.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_495.tif': 2, '../../../smalldataset/data/CBFB_MYH11/BTB/image_192.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_65.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_405.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_148.tif': 1, '../../../smalldataset/data/control/BXR/image_381.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_243.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_262.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_5.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_262.tif': 2, '../../../smalldataset/data/NPM1/ALA/image_487.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK ...
# Generating data for patient 4 of subtype CBFB_MYH11...
# 		Selected 0 images for eosinophil granulocyte
# 		Selected 6 images for reactive lymphocyte
# 		Selected 27 images for neutrophil granulocyte (segmented)
# 		Selected 127 images for typical lymphocyte
# 		Selected 23 images for other
# 		Selected 6 images for neutrophil granulocyte (band)
# 		Selected 0 images for monocyte
# 		Selected 18 images for large granulated lymphocyte
# 		Selected 12 images for atypical promyelocyte
# 		Selected 0 images for basophil granulocyte
# 		Selected 0 images for smudge cell
# 		Selected 1 images for neoplastic lymphocyte
# 		Selected 0 images for promyelocyte
# 		Selected 0 images for myelocyte
# 		Selected 167 images for myeloblast
# 		Selected 4 images for metamyelocyte
# 		Selected 5 images for normo
# 		Selected 6 images for plasma cell
# 		Selected 1 images for hair cell
# 		Selected 2 images for bilobed M3v
# 		Selected 16 images for mononucleosis
# 	Cell type count for patient 4: {'../../../smalldataset/data/CBFB_MYH11/BJK/image_1.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_28.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_468.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_441.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_127.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_324.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_200.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_182.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_90.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_48.tif': 1, '../../../smalldataset/data/control/BXR/image_293.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_221.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_414.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_115.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_82.tif': 1, '../../../smalldataset/data/control/ATM/image_269.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_310.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_167.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_425.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_313.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_460.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_175.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_115.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_412.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_354.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_215.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_362.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_387.tif': 2, '../../../smalldataset/data/NPM1/DPF/image_411.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_263.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_364.tif': 2, '../../../smalldataset/data/NPM1/ALA/image_479.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_123.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_43.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_104.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_105.tif': 1, '../../../smalldataset/data/control/AVL/image_27.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_63.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_104.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_186.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_313.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_163.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_204.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_39.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_418.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_256.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_350.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_349.tif': 1, '../../../smalldataset/data/control/AEC/image_209.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_93.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_10.tif': 1, '../../../smalldataset/data/control/AEC/image_405.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_93.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_213.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_488.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_389.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_407.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_217.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_269.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_6.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_371.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_121.tif': 2, '../../../smalldataset/data/PML_RARA/BIK/image_82.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_470.tif': 1, '../../../smalldataset/data/control/AEC/image_413.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_276.tif': 1, '../../../sma ...
# 	Cell type counts dictionary for patient CBFB_MYH11/patient_4: {'../../../smalldataset/data/CBFB_MYH11/BJK/image_1.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_28.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_468.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_441.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_127.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_324.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_200.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_182.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_90.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_48.tif': 1, '../../../smalldataset/data/control/BXR/image_293.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_221.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_414.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_115.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_82.tif': 1, '../../../smalldataset/data/control/ATM/image_269.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_310.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_167.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_425.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_313.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_460.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_175.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_115.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_412.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_354.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_215.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_362.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_387.tif': 2, '../../../smalldataset/data/NPM1/DPF/image_411.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_263.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_364.tif': 2, '../../../smalldataset/data/NPM1/ALA/image_479.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_123.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_43.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_104.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_105.tif': 1, '../../../smalldataset/data/control/AVL/image_27.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_63.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_104.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_186.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_313.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_163.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_204.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_39.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_418.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_256.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_350.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_349.tif': 1, '../../../smalldataset/data/control/AEC/image_209.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_93.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_10.tif': 1, '../../../smalldataset/data/control/AEC/image_405.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_93.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_213.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_488.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_389.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_407.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_217.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_269.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_6.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_371.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_121.tif': 2, '../../../smalldataset/data/PML_RARA/BIK/image_82.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_470.tif': 1, '../../../smalldataset/data/control/AEC/image_413.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/i ...
# Generating data for patient 5 of subtype CBFB_MYH11...
# 		Selected 0 images for eosinophil granulocyte
# 		Selected 1 images for reactive lymphocyte
# 		Selected 23 images for neutrophil granulocyte (segmented)
# 		Selected 103 images for typical lymphocyte
# 		Selected 15 images for other
# 		Selected 2 images for neutrophil granulocyte (band)
# 		Selected 56 images for monocyte
# 		Selected 8 images for large granulated lymphocyte
# 		Selected 11 images for atypical promyelocyte
# 		Selected 0 images for basophil granulocyte
# 		Selected 0 images for smudge cell
# 		Selected 1 images for neoplastic lymphocyte
# 		Selected 0 images for promyelocyte
# 		Selected 2 images for myelocyte
# 		Selected 100 images for myeloblast
# 		Selected 1 images for metamyelocyte
# 		Selected 1 images for normo
# 		Selected 3 images for plasma cell
# 		Selected 0 images for hair cell
# 		Selected 1 images for bilobed M3v
# 		Selected 22 images for mononucleosis
# 	Cell type count for patient 5: {'../../../smalldataset/data/CBFB_MYH11/DQV/image_485.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_111.tif': 1, '../../../smalldataset/data/control/BXR/image_1.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_482.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_358.tif': 1, '../../../smalldataset/data/control/AEC/image_303.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_160.tif': 1, '../../../smalldataset/data/control/BXR/image_275.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_196.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_35.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_243.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_221.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_370.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_125.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_113.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_289.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_161.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_414.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_115.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_468.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_366.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_116.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_296.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_234.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_125.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_298.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_459.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_140.tif': 2, '../../../smalldataset/data/CBFB_MYH11/AQK/image_29.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_429.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_1.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_388.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_364.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_326.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_410.tif': 1, '../../../smalldataset/data/control/AIH/image_22.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_319.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_182.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_434.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_353.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_220.tif': 2, '../../../smalldataset/data/CBFB_MYH11/DQV/image_39.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_381.tif': 1, '../../../smalldataset/data/control/AVL/image_198.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_411.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_74.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_93.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_98.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_319.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_106.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_387.tif': 1, '../../../smalldataset/data/control/BXR/image_32.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_300.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_171.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_197.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_1.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_182.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_29.tif': 1, '../../../smalldataset/data/control/AVL/image_127.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_167.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_210.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_232.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_141.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_41.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_459.tif': 1, '../../../smalldataset/data/control/AVL/image_69.tif': 1, '../.. ...
# 	Cell type counts dictionary for patient CBFB_MYH11/patient_5: {'../../../smalldataset/data/CBFB_MYH11/DQV/image_485.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_111.tif': 1, '../../../smalldataset/data/control/BXR/image_1.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_482.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_358.tif': 1, '../../../smalldataset/data/control/AEC/image_303.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_160.tif': 1, '../../../smalldataset/data/control/BXR/image_275.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_196.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_35.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_243.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_221.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_370.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_125.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_113.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_289.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_161.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_414.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_115.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_468.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_366.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_116.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_296.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_234.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_125.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_298.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_459.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_140.tif': 2, '../../../smalldataset/data/CBFB_MYH11/AQK/image_29.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_429.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_1.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_388.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_364.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_326.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_410.tif': 1, '../../../smalldataset/data/control/AIH/image_22.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_319.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_182.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_434.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_353.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_220.tif': 2, '../../../smalldataset/data/CBFB_MYH11/DQV/image_39.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_381.tif': 1, '../../../smalldataset/data/control/AVL/image_198.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_411.tif': 1, '../../../smalldataset/data/NPM1/DPF/image_74.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_93.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_98.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_319.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_106.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_387.tif': 1, '../../../smalldataset/data/control/BXR/image_32.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_300.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_171.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_197.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_1.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_182.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_29.tif': 1, '../../../smalldataset/data/control/AVL/image_127.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_167.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_210.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_232.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_141.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_41.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_459.tif': 1, '../../../smalldataset/data/contr ...
# Generating data for patient 1 of subtype control...
# 		Selected 19 images for eosinophil granulocyte
# 		Selected 3 images for reactive lymphocyte
# 		Selected 203 images for neutrophil granulocyte (segmented)
# 		Selected 68 images for typical lymphocyte
# 		Selected 70 images for other
# 		Selected 17 images for neutrophil granulocyte (band)
# 		Selected 21 images for monocyte
# 		Selected 31 images for large granulated lymphocyte
# 		Selected 0 images for atypical promyelocyte
# 		Selected 7 images for basophil granulocyte
# 		Selected 0 images for smudge cell
# 		Selected 0 images for neoplastic lymphocyte
# 		Selected 0 images for promyelocyte
# 		Selected 0 images for myelocyte
# 		Selected 0 images for myeloblast
# 		Selected 0 images for metamyelocyte
# 		Selected 1 images for normo
# 		Selected 0 images for plasma cell
# 		Selected 1 images for hair cell
# 		Selected 0 images for bilobed M3v
# 		Selected 3 images for mononucleosis
# ...
# 	Cell type counts dictionary for patient RUNX1_RUNX1T1/patient_5: {'../../../smalldataset/data/CBFB_MYH11/BSN/image_176.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_312.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_206.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_16.tif': 1, '../../../smalldataset/data/NPM1/CVW/image_153.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_373.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_343.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_137.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_440.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_324.tif': 1, '../../../smalldataset/data/control/AEC/image_139.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/ABF/image_161.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_166.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_151.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_296.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_161.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_198.tif': 1, '../../../smalldataset/data/control/AVL/image_305.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_459.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_312.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_105.tif': 2, '../../../smalldataset/data/NPM1/BHR/image_82.tif': 1, '../../../smalldataset/data/control/AEC/image_313.tif': 1, '../../../smalldataset/data/PML_RARA/BIK/image_32.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_431.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_336.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_180.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_107.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_283.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_224.tif': 1, '../../../smalldataset/data/PML_RARA/ALE/image_320.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_472.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_352.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_381.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_408.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_216.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BKR/image_313.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_481.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BOE/image_248.tif': 1, '../../../smalldataset/data/control/BXR/image_354.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_58.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_54.tif': 1, '../../../smalldataset/data/PML_RARA/BHS/image_259.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_125.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_76.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BSN/image_207.tif': 1, '../../../smalldataset/data/control/BXR/image_259.tif': 1, '../../../smalldataset/data/NPM1/ALA/image_87.tif': 1, '../../../smalldataset/data/control/AIH/image_55.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BJK/image_74.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_86.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/DHA/image_274.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_418.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_228.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_23.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_55.tif': 1, '../../../smalldataset/data/NPM1/BHR/image_272.tif': 1, '../../../smalldataset/data/PML_RARA/CWF/image_149.tif': 1, '../../../smalldataset/data/CBFB_MYH11/BTB/image_5.tif': 1, '../../../smalldataset/data/NPM1/CZI/image_63.tif': 1, '../../../smalldataset/data/PML_RARA/CMR/image_78.tif': 1, '../../../smalldataset/data/CBFB_MYH11/AQK/image_15.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_204.tif': 1, '../../../smalldataset/data/RUNX1_RUNX1T1/BHG/image_369.tif': 1, '../../../smalldataset/data/CBFB_MYH11/DQV/image_496.tif': 1, '.. ...
#
# Selected Images Count per SC class per Patient:
# CBFB_MYH11/patient_1
# 	eosinophil granulocyte: 3
# 	reactive lymphocyte: 4
# 	neutrophil granulocyte (segmented): 8
# 	typical lymphocyte: 42
# 	other: 19
# 	neutrophil granulocyte (band): 12
# 	monocyte: 155
# 	large granulated lymphocyte: 44
# 	atypical promyelocyte: 8
# 	basophil granulocyte: 0
# 	smudge cell: 18
# 	neoplastic lymphocyte: 2
# 	promyelocyte: 0
# 	myelocyte: 1
# 	myeloblast: 111
# 	metamyelocyte: 3
# 	normo: 5
# 	plasma cell: 6
# 	hair cell: 0
# 	bilobed M3v: 0
# 	mononucleosis: 29
# CBFB_MYH11/patient_2
# 	eosinophil granulocyte: 1
# 	reactive lymphocyte: 9
# 	neutrophil granulocyte (segmented): 13
# 	typical lymphocyte: 15
# 	other: 27
# 	neutrophil granulocyte (band): 11
# 	monocyte: 76
# 	large granulated lymphocyte: 0
# 	atypical promyelocyte: 20
# 	basophil granulocyte: 0
# 	smudge cell: 0
# 	neoplastic lymphocyte: 2
# 	promyelocyte: 2
# 	myelocyte: 1
# 	myeloblast: 150
# 	metamyelocyte: 6
# 	normo: 6
# 	plasma cell: 12
# 	hair cell: 0
# 	bilobed M3v: 0
# 	mononucleosis: 0
# CBFB_MYH11/patient_3
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 12
# 	neutrophil granulocyte (segmented): 2
# 	typical lymphocyte: 19
# 	other: 13
# 	neutrophil granulocyte (band): 5
# 	monocyte: 129
# 	large granulated lymphocyte: 27
# 	atypical promyelocyte: 1
# 	basophil granulocyte: 0
# 	smudge cell: 13
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 0
# 	myelocyte: 0
# 	myeloblast:
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 4
# 	myelocyte: 12
# 	myeloblast: 174
# 	metamyelocyte: 30
# 	normo: 3
# 	plasma cell: 32
# 	hair cell: 2
# 	bilobed M3v: 9
# 	mononucleosis: 4
# RUNX1_RUNX1T1/patient_3
# 	eosinophil granulocyte: 1
# 	reactive lymphocyte: 1
# 	neutrophil granulocyte (segmented): 13
# 	typical lymphocyte: 99
# 	other: 6
# 	neutrophil granulocyte (band): 26
# 	monocyte: 26
# 	large granulated lymphocyte: 8
# 	atypical promyelocyte: 26
# 	basophil granulocyte: 0
# 	smudge cell: 38
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 0
# 	myelocyte: 4
# 	myeloblast: 179
# 	metamyelocyte: 4
# 	normo: 2
# 	plasma cell: 28
# 	hair cell: 3
# 	bilobed M3v: 0
# 	mononucleosis: 0
# RUNX1_RUNX1T1/patient_4
# 	eosinophil granulocyte: 3
# 	reactive lymphocyte: 0
# 	neutrophil granulocyte (segmented): 12
# 	typical lymphocyte: 0
# 	other: 7
# 	neutrophil granulocyte (band): 1
# 	monocyte: 37
# 	large granulated lymphocyte: 7
# 	atypical promyelocyte: 23
# 	basophil granulocyte: 0
# 	smudge cell: 6
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 7
# 	myelocyte: 10
# 	myeloblast: 169
# 	metamyelocyte: 0
# 	normo: 3
# 	plasma cell: 21
# 	hair cell: 0
# 	bilobed M3v: 0
# 	mononucleosis: 1
# RUNX1_RUNX1T1/patient_5
# 	eosinophil granulocyte: 3
# 	reactive lymphocyte: 1
# 	neutrophil granulocyte (segmented): 32
# 	typical lymphocyte: 107
# 	other: 15
# 	neutrophil granulocyte (band): 0
# 	monocyte: 36
# 	large granulated lymphocyte: 8
# 	atypical promyelocyte: 17
# 	basophil granulocyte: 0
# 	smudge cell: 8
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 10
# 	myelocyte: 0
# 	myeloblast: 262
# 	metamyelocyte: 14
# 	normo: 6
# 	plasma cell: 9
# 	hair cell: 0
# 	bilobed M3v: 14
# 	mononucleosis: 8

# %%
#saving images in npy files
for aml_subtype in class_labels:
    output_class_folder=output_folder+"/"+aml_subtype    
    for patient_number in range(n_patients):
        patient_folder = os.path.join(output_class_folder, f'patient_{patient_number+1}')
        print(patient_folder)
        with open( os.path.join(patient_folder,"image_file_paths") ,'rb') as fp:
            image_file_paths=pickle.load(fp)
        array_list=[]
        previous_patient_id=None
        # Iterate through each image path
        for image_path in image_file_paths:
            patient_id = image_path[:image_path.find("/image")]
            if previous_patient_id!=patient_id:
                #print(f"New patient: {patient_id}, old patient : {previous_patient_id}")
                features=np.load(patient_id+"/fnl34_bn_features_layer_7.npy")
            array_list.append([features[extract_number_image(image_path)]])
            previous_patient_id=patient_id 
        #Concatenate all features for one artificial patient    
        artificial_features = np.concatenate(array_list,axis=0)
        output_npy_file = output_folder+f"/{aml_subtype}/patient_{patient_number+1}/fnl34_bn_features_layer_7.npy"
        # Save the array to the .npy file
        np.save(output_npy_file, artificial_features)

# %%
#Create metadata including single cell types, not including age, gender and leucocytes_per_µl
# Create a list to hold the rows of the DataFrame
rows = []
'''sc_class_labels= ['eosinophil granulocyte', 'reactive lymphocyte',
       'neutrophil granulocyte (segmented)', 'typical lymphocyte',
       'other', 'neutrophil granulocyte (band)', 'monocyte',
       'large granulated lymphocyte', 'atypical promyelocyte',
       'basophil granulocyte', 'smudge cell', 'neoplastic lymphocyte',
       'promyelocyte', 'myelocyte', 'myeloblast', 'metamyelocyte',
       'normo', 'plasma cell', 'hair cell', 'bilobed M3v',
       'mononucleosis']'''

# Fill in the DataFrame with values from the dictionary
for patient_id, cell_counts in selected_images_per_patient.items():
    myeloblast_count = cell_counts.get('myeloblast', 0)
    # Extract counts for other cell types
    promyelocyte_count = cell_counts.get('promyelocyte', 0)
    myelocyte_count = cell_counts.get('myelocyte', 0)
    metamyelocyte_count = cell_counts.get('metamyelocyte', 0)
    neutrophil_band_count = cell_counts.get('neutrophil granulocyte (band)', 0)
    neutrophil_segmented_count = cell_counts.get('neutrophil granulocyte (segmented)', 0)
    eosinophil_count = cell_counts.get('eosinophil granulocyte', 0)
    basophil_count = cell_counts.get('basophil granulocyte', 0)
    monocyte_count = cell_counts.get('monocyte', 0)
    lymph_typ_count = cell_counts.get('typical lymphocyte', 0)
    lymph_atyp_react_count = cell_counts.get('reactive lymphocyte', 0)
    lymph_atyp_neopl_count = cell_counts.get('neoplastic lymphocyte', 0)
    other_count = cell_counts.get('other', 0)
    total_count = sum(cell_counts.values())#check

  
    index = patient_id.find("/patient")
    bag = patient_id[:index] if index != -1 else patient_id

    id = patient_id.find("/")
    patient = patient_id[id + 1:] if index != -1 else ""

    age = 0 #dummy
    row = {'patient_id': patient,
           'sex_1f_2m': None,  # Placeholder value
           'age': age,
           'bag_label': bag, 
           'instance_count': total_count,#check
           'leucocytes_per_µl': None,  # Placeholder value
           'pb_myeloblast': round((myeloblast_count/total_count)*100,1),
           'pb_promyelocyte': round((promyelocyte_count/total_count)*100,1),
           'pb_myelocyte': round((myelocyte_count/total_count)*100,1),
           'pb_metamyelocyte': round((metamyelocyte_count/total_count)*100,1),
           'pb_neutrophil_band': round((neutrophil_band_count/total_count)*100,1),
           'pb_neutrophil_segmented': round((neutrophil_segmented_count/total_count)*100,1),
           'pb_eosinophil': round((eosinophil_count/total_count)*100,1),
           'pb_basophil': round((basophil_count/total_count)*100,1),
           'pb_monocyte': round((monocyte_count/total_count)*100,1),
           'pb_lymph_typ': round((lymph_typ_count/total_count)*100,1),
           'pb_lymph_atyp_react': round((lymph_atyp_react_count/total_count)*100,1),
           'pb_lymph_atyp_neopl': round((lymph_atyp_neopl_count/total_count)*100,1),
           'pb_other': round((other_count/total_count)*100,1),
           'pb_total': round((total_count/total_count)*100,1)}#check
    rows.append(row)

# Create DataFrame from the list of rows
artificial_metadata = pd.DataFrame(rows)

# Save the DataFrame to a CSV file
metadata_csv_path = os.path.join(output_folder_csv, 'metadata.csv')
artificial_metadata.to_csv(metadata_csv_path, index=False)
print(f"Metadata saved to {metadata_csv_path}")
# Out:
# Metadata saved to ../../../artificialdata/experiment_3/metadata.csv
